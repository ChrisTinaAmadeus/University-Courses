# %% [markdown]
# # 面向对象练习

# %%
class A(object):
    def __init__(self):
        print("A() is created")

a = A()
a1 = A()
a2 = A()
# Out:
# A() is created
# A() is created
# A() is created

# %%
class B(A):
    pass

b = B()
# Out:
# A() is created

# %%
class B2(A):
    def __init__(self):
        print('I am called')
        #pass

b2 = B2()
# Out:
# I am called

# %%
class B3(A):
    def __init__(self):
        super().__init__()
        print('I am called')
        #pass

b3 = B3()
# Out:
# A() is created
# I am called

# %%
class A5(object):
    pass

class A2(object):
    #def __init__(self):
    #    print("A2()")
        
    def __init__(self, name):
        self.name = name
        print("A() is created, ", name)

a0 = A5()
a1 = A2('A1')
a2 = A2()
# Out:
# A() is created,  A1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-7699251b743e> in <module>
#      12 a0 = A5()
#      13 a1 = A2('A1')
# ---> 14 a2 = A2()
#
# TypeError: __init__() missing 1 required positional argument: 'name'

# %%
class B2(A2):
    def __init__(self, name):
        super().__init__(name)

b = B2('hello')
# Out:
# A() is created,  hello

# %%
class D(object):
    def __init__(self, name):
        self.name = name
        print("D() is created ", name)
    def hello(self):
        print("hello is called")
        print("hello world ", self.name)

d = D("Dragon")
d.hello()
#print(d.name)
# Out:
# D() is created  Dragon
# hello is called
# hello world  Dragon

# %%
class C(D):
    def __init__(self):
        super().__init__('xxx')#
        print("C()")

c = C()
c.hello()
# Out:
# C()
# hello is called
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-39ff3d724f7a> in <module>
#       5
#       6 c = C()
# ----> 7 c.hello()
#
# <ipython-input-20-a954f1e5bff1> in hello(self)
#       5     def hello(self):
#       6         print("hello is called")
# ----> 7         print("hello world ", self.name)
#       8
#       9 d = D("Dragon")
#
# AttributeError: 'C' object has no attribute 'name'

# %%
class Student(object):
    
    def __init__(self, name, scores):
        self.name = name
        self.scores = scores
    
    def __iter__(self):
        return iter(self.scores)
    
    def __len__(self):
        return len(self.scores)
    
    def __getitem__(self, index):
        return self.scores[index]

    def __repr__(self):
        return "[" + self.name + "\n" + ' '.join(map(str,scores)) + "]"

# %%
scores = [80, 90, 100]
name = 'Tom'

tom = Student(name, scores)

print("Test __repr__")
print(tom)  #__repr__


print("Test __getitem__")
print(tom[1]) #__getitem__

print("Test __len__")
print(len(tom)) #__len__

print("Test __iter__")
for x in tom: #__iter__
    print(x)
# Out:
# Test __repr__
# [Tom
# 80 90 100]
# Test __getitem__
# 90
# Test __len__
# 3
# Test __iter__
# 80
# 90
# 100
